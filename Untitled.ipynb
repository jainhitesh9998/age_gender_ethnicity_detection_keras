# %%
from wide_resnet import wide_resnet
from utils import utils
# Out:
# /home/hitesh/miniconda3/envs/carnd-term1/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# Using TensorFlow backend.
# /home/hitesh/miniconda3/envs/carnd-term1/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/hitesh/miniconda3/envs/carnd-term1/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
import sklearn
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
import os
import numpy as np

# %%
def generator(samples, batch_size = 32): 
    num_samples = len(samples)
    print(num_samples)
    while 1: #to run the generator indefinitely, pumping the X, Y sets for the neural network
        #shuffle the samples on each EPOCH
        sklearn.utils.shuffle(samples)
        for offset in range(0, num_samples, batch_size):
            batch_samples = samples[offset: offset + batch_size]
            labels = []
            images = []
            ages = []
            genders = []
            races = []
            age = []
            gender = []
            race = []
            for batch_sample in batch_samples:
                path, a, g, r = batch_sample
                name =  os.path.split(batch_sample[0])[-1]
                image = utils.read_image(path)
                #print(image.shape)
                if(a>100):
                  continue
                images.append(image)
                age.append(a)
                gender.append(abs(1 - g))
                race.append(r)
            ages = to_categorical(age, num_classes=101)
            genders = to_categorical(gender, num_classes=2)
            races = to_categorical(race, num_classes=5)
            labels = [np.array(genders), np.array(ages), np.array(races)]
            X_train = np.array(images)
            yield X_train,labels

# %%
samples = utils.read_csv('extras/data.csv')

# %%
samples[1:10]
# Out:
# [['dataset/crop_part1/2_1_4_20161221195838329.jpg.chip.jpg', 2, 1, 4],
#  ['dataset/crop_part1/85_1_0_20170110181617775.jpg.chip.jpg', 85, 1, 0],
#  ['dataset/crop_part1/85_1_0_20170110183616456.jpg.chip.jpg', 85, 1, 0],
#  ['dataset/crop_part1/31_1_3_20170109132020731.jpg.chip.jpg', 31, 1, 3],
#  ['dataset/crop_part1/6_0_0_20170110215527972.jpg.chip.jpg', 6, 0, 0],
#  ['dataset/crop_part1/16_1_4_20170103234142187.jpg.chip.jpg', 16, 1, 4],
#  ['dataset/crop_part1/60_1_0_20170110160643720.jpg.chip.jpg', 60, 1, 0],
#  ['dataset/crop_part1/7_1_4_20161224001014334.jpg.chip.jpg', 7, 1, 4],
#  ['dataset/crop_part1/1_0_2_20161219204858548.jpg.chip.jpg', 1, 0, 2]]

# %%
model = wide_resnet.WideResNet(image_size = 64,race = True, train_branch=True)()

# %%
for layer in model.layers:
    print (layer.trainable)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# False
# True
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# False
# True

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['mae', 'acc'])


sklearn.utils.shuffle(samples)
train_samples, validation_samples = train_test_split(samples, test_size=0.2)
print(train_samples[1])
# Out:
# ['dataset/UTKFace/76_0_1_20170116205605555.jpg.chip.jpg', 76, 0, 1]

# %%
#Hyperparameters
train_generator = generator(train_samples, 4)
validation_generator = generator(validation_samples, 4)
epoch = 3
#end of hyperparameters

history = model.fit_generator(train_generator, samples_per_epoch = len(train_samples), validation_data = validation_generator,\
                   nb_val_samples = len(validation_samples), nb_epoch = epoch)
model.save("model_new.h5")
# Out:
# /home/hitesh/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/ipykernel_launcher.py:9: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if __name__ == '__main__':
# /home/hitesh/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/ipykernel_launcher.py:9: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., epochs=3, validation_data=<generator..., validation_steps=6692, steps_per_epoch=26767)`
#   if __name__ == '__main__':
# 26767Epoch 1/3
#
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
#     1/26767 [..............................] - ETA: 113:36:41 - loss: 9.0950 - gender_detection_loss: 0.5944 - age_detection_loss: 4.4361 - race_loss: 1.8202 - gender_detection_mean_absolute_error: 0.4448 - gender_detection_acc: 1.0000 - age_detection_mean_absolute_error: 0.0193 - age_detection_acc: 0.0000e+00 - race_mean_absolute_error: 0.3347 - race_acc: 0.0000e+00(64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
- age_detection_mean_absolute_error: 0.0194 - age_detection_acc: 0.0312 - race_mean_absolute_error: 0.2225 - race_acc: 0.4375(64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
#    33/26767 [..............................] - ETA: 8:05:01 - loss: 15.7927 - gender_detection_loss: 0.6164 - age_detection_loss: 4.7240 - race_loss: 8.2558 - gender_detection_mean_absolute_error: 0.4146 - gender_detection_acc: 0.6591 - age_detection_mean_absolute_error: 0.0194 - age_detection_acc: 0.0303 - race_mean_absolute_error: 0.2188 - race_acc: 0.4470(64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
#    34/26767 [..............................] - ETA: 7:59:19 - loss: 15.6547 - gender_detection_loss: 0.6167 - age_detection_loss: 4.7144 - race_loss: 8.1315 - gender_detection_mean_absolute_error: 0.4151 - gender_detection_acc: 0.6544 - age_detection_mean_absolute_error: 0.0194 - age_detection_acc: 0.0294 - race_mean_absolute_error: 0.2153 - race_acc: 0.4559(64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
#    35/26767 [..............................] - ETA: 7:53:34 - loss: 15.8560 - gender_detection_loss: 0.6180 - age_detection_loss: 4.6906 - race_loss: 8.3597 - gender_detection_mean_absolute_error: 0.4160 - gender_detection_acc: 0.6500 - age_detection_mean_absolute_error: 0.0194 - age_detection_acc: 0.0286 - race_mean_absolute_error: 0.2206 - race_acc: 0.4429(64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-75687b339cdb> in <module>()
#       7 #end of hyperparameters
#       8
# ----> 9 history = model.fit_generator(train_generator, samples_per_epoch = len(train_samples), validation_data = validation_generator,                   nb_val_samples = len(validation_samples), nb_epoch = epoch)
#      10 model.save("model_new.h5")
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2075                     outs = self.train_on_batch(x, y,
#    2076                                                sample_weight=sample_weight,
# -> 2077                                                class_weight=class_weight)
#    2078
#    2079                     if not isinstance(outs, list):
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1795             ins = x + y + sample_weights
#    1796         self._make_train_function()
# -> 1797         outputs = self.train_function(ins)
#    1798         if len(outputs) == 1:
#    1799             return outputs[0]
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2330         updated = session.run(self.outputs + [self.updates_op],
#    2331                               feed_dict=feed_dict,
# -> 2332                               **self.session_kwargs)
#    2333         return updated[:len(self.outputs)]
#    2334
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
model.save('temp.h5')

# %%
from wide_resnet import wide_resnet
from utils import utils
import sklearn
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
import os
import numpy as np

def generator(samples, batch_size = 32):
    num_samples = len(samples)
    print(num_samples)
    while 1: #to run the generator indefinitely, pumping the X, Y sets for the neural network
        #shuffle the samples on each EPOCH
        sklearn.utils.shuffle(samples)
        for offset in range(0, num_samples, batch_size):
            batch_samples = samples[offset: offset + batch_size]
            labels = []
            images = []
            ages = []
            genders = []
            races = []
            age = []
            gender = []
            race = []
            for batch_sample in batch_samples:
                path, a, g, r = batch_sample
                name =  os.path.split(batch_sample[0])[-1]
                image = utils.read_image(path)
                #print(image.shape)
                if(a>100):
                  continue
                images.append(image)
                age.append(a)
                gender.append(abs(1 - g))
                race.append(r)
            ages = to_categorical(age, num_classes=101)
            genders = to_categorical(gender, num_classes=2)
            races = to_categorical(race, num_classes=5)
            labels = [np.array(genders), np.array(ages), np.array(races)]
            X_train = np.array(images)
            yield X_train,labels

def main():
    samples = utils.read_csv('extras/data.csv')
    model = wide_resnet.WideResNet(image_size=64, race=True, train_branch=True)()
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['mae', 'acc'])
    sklearn.utils.shuffle(samples)
    train_samples, validation_samples = train_test_split(samples, test_size=0.2)
    # Hyperparameters
    train_generator = generator(train_samples, 4)
    validation_generator = generator(validation_samples, 4)
    epoch = 3
    # end of hyperparameters

    history = model.fit_generator(train_generator, samples_per_epoch=len(train_samples),
                                  validation_data=validation_generator, \
                                  nb_val_samples=len(validation_samples), nb_epoch=epoch)
    model.save(os.path.join('weights','model_new.h5'))

main()
